# %% [markdown]
# # Exploring Ebay Car Sales

# %%
# Importing Libraries
import pandas as pd
import numpy as np
# Import csv file to variable
autos = pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
# Let's start with some information
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# ### Based on the information, we do need some data cleaning
# - some variables have mixed strings and numbers
# - dates are in string format
# - name variable needs to separate the brand, model, & number
# - probably, some have null values
# - column names use [camelcase](https://en.wikipedia.org/wiki/Camel_case) instead of Python's preferred [snakecase](https://en.wikipedia.org/wiki/Snake_case)

# %%
# Let's clean the columns first
# Make a map dictionary for the ff columns
column_dict = {'yearOfRegistration': 'registration_year',
                'monthOfRegistration': 'registration_month',
                'notRepairedDamage': 'unrepaired_damage',
                'dateCreated': 'ad_created'
}
# Built-in rename function to rename columns
autos.rename(columns=column_dict, inplace=True)
# Make new variable for columns list and modified back to the dataframe
column_names = list(autos.columns)
# Make a function to change camelcase to snakecase
def change_case_string(name):
    new_name = ""
    for character in name:
        if character.isupper():
            # if found, change to lower and add underscore char
            character = "_" + character.lower()
            new_name += character
        else:
            new_name += character
    return new_name

def clean_list_case(lists):
    # Made list comprehension for one line code
#     new_lists = []
#     for item in lists:
#         new_lists.append(change_case_string(item))    
    return [change_case_string(item) for item in lists]

autos.columns = clean_list_case(column_names)

# %%
# Let's see the new column names
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_p_s', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.describe(include='all')
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-10 15:36:24  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox     power_p_s  model  \
# ...

# %%
autos.tail(2)
# Out:
#               date_crawled                                name  seller  \
# 49998  2016-03-08 19:25:42  Audi_A3_2.0_TDI_Sportback_Ambition  privat
# 49999  2016-03-14 00:42:12                 Opel_Vectra_1.6_16V  privat
#
#       offer_type    price   abtest vehicle_type  registration_year  gearbox  \
# 49998    Angebot  $22,900  control        kombi               2013  manuell
# 49999    Angebot   $1,250  control    limousine               1996  manuell
#
#        power_p_s   model   odometer  registration_month fuel_type brand  \
# 49998        150      a3   40,000km                  11    diesel  audi
# 49999        101  vectra  150,000km                   1    benzin  opel
#
#       unrepaired_damage           ad_created  nr_of_pictures  postal_code  \
# 49998              nein  2016-03-08 00:00:00               0        35683
# 49999              nein  2016-03-13 00:00:00               0        45897
#
#                  last_seen
# 49998  2016-04-05 16:45:07
# ...

# %% [markdown]
# ### Price and Odometer have mixed string and number. Do some data cleaning. Columns that perharps could be dropped
# - seller
# - offer type
# - unrepaired damage
# - nr of pictures

# %%
# Check unique records for price and odometer
print(autos['price'].unique(), len(autos['price'].unique()))
# Out:
# ['$5,000' '$8,500' '$8,990' ... '$385' '$22,200' '$16,995'] 2357

# %%
print(autos['odometer'].unique(), len(autos['odometer'].unique()))
# Out:
# ['150,000km' '70,000km' '50,000km' '80,000km' '10,000km' '30,000km'
#  '125,000km' '90,000km' '20,000km' '60,000km' '5,000km' '100,000km'
#  '40,000km'] 13

# %% [markdown]
# The strings of price column are '$' and ','.
# While strings of odometer are ',', 'km' and 'k'.

# %%
# Cleaning price and odometer records
autos['price'] = autos['price'].str.replace('$','')
autos['price'] = autos['price'].str.replace(',','')
# Convert to numberic dtype
autos['price'] = autos['price'].astype(int)
# for odometer
autos['odometer'] = autos['odometer'].str.replace(',','')
autos['odometer'] = autos['odometer'].str.replace('km','')
autos['odometer'] = autos['odometer'].str.replace('k','')
autos['odometer'] = autos['odometer'].astype(int)

# %%
# Let's check if records of price and odometer are w/o missing values to double check if we miss characters we haven't clean
autos['price'].isnull().sum()
# Out:
# 0

# %%
# For odometer
autos['odometer'].isnull().sum()
# Out:
# 0

# %%
# Rename the column to odometer_km
autos.rename(columns={'odometer' : 'odometer_km'}, inplace=True)

# %%
# Let's see which columns have missing values
autos.isnull().sum()
# Out:
# date_crawled             0
# name                     0
# seller                   0
# offer_type               0
# price                    0
# abtest                   0
# vehicle_type          5095
# registration_year        0
# gearbox               2680
# power_p_s                0
# model                 2758
# odometer_km              0
# registration_month       0
# fuel_type             4482
# brand                    0
# unrepaired_damage     9829
# ad_created               0
# nr_of_pictures           0
# postal_code              0
# last_seen                0
# dtype: int64

# %% [markdown]
# ### Let's contiue exploring the data of odometer_km and price
# - Series.unique().shape to see how many unique values
# - Series.describe() to view min/max/median/mean etc
# - Series.value_counts(), with some variations: .head() , .sort_index()
# - When removing outliers, we can do df[(df["col"] > x ) & (df["col"] < y )], but it's more readable to use df[df["col"].between(x,y)]

# %%
autos['price'].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
# seeing the max seems there is outliers
autos['price'].max()
# Out:
# 99999999

# %%
price_bool_1 = autos["price"] == 99999999 # 12345678 gives you 3 records
print(autos['price'].loc[price_bool_1].value_counts())
# Out:
# 99999999    1
# Name: price, dtype: int64

# %%
# There's no car price for zero amount
price_bool_2 = autos["price"] == 0
print(autos['price'].loc[price_bool_2].value_counts())
# Out:
# 0    1421
# Name: price, dtype: int64

# %%
# Display possible outliers of price
# if mean is around 9840 then more than 10k could be outliers
x = 99999999
y = 10000 # 999999 results 13 records only
price_outliers = autos[autos["price"].between(y,x)]
price_outliers
# Out:
#               date_crawled                                               name  \
# 15     2016-04-01 12:06:20        Corvette_C3_Coupe_T_Top_Crossfire_Injection
# 21     2016-03-06 19:07:10                      Porsche_911_Carrera_4S_Cabrio
# 22     2016-03-28 20:50:54                               MINI_Cooper_S_Cabrio
# 24     2016-04-03 11:57:02                         BMW_535i_xDrive_Sport_Aut.
# 37     2016-03-23 16:47:46                 Seat_Altea_XL_2.0_TDI_CR_DPF_Style
# 42     2016-03-22 21:37:03  Vw_Polo_l.0_/60_PS_Blue_Motion_Technologie_Son...
# 43     2016-03-08 16:51:22           Audi_A1_1.2_TFSI_Attraction_mit_Garantie
# 49     2016-03-27 15:36:42    Mercedes_Benz_CL_500__BlueEFFICIENCY__7G_TRONIC
# 63     2016-03-14 22:51:19                   MINI_Mini_Cooper_S___Xenon_Leder
# 68     2016-04-03 17:36:59  Mini_cooper_s_clubman_/vollausstattung_/_Navi/...
# 76     2016-03-22 14:52:57                         BMW_318i_neustes_Model_0Km
# ...

# %%
# Total of ouliers that is price > 10k
len(price_outliers)
# Out:
# 8181

# %%
# Let's look at odometer_km
autos['odometer_km'].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos['odometer_km'].value_counts()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %% [markdown]
# ### Analyzing of price and odometer
# Data of odometer_km seems fine. But price has lots of outliers. If we see the mean of price is around 10k, then around 8.1k (price > 10k) records would be outliers. We find out that price with zero amount has around 1.4k. So if we removed around 9.5k outliers records, the remaining records would be around 40k. Still, we still has a good data if we drop the 9.5k outliers. If not, we can replace the outliers with mean.

# %%
# Let's drop the outliers of price
# Deciding that price > 10000 or < 100 are to be dropped
autos.drop(autos.index[((autos['price'] > 10000) |
                        (autos['price'] < 100))],
                        axis=0, inplace=True)

# %% [markdown]
# ### Let's go to date columns and analyze the data on how to clean it
# - `date_crawled`: added by the crawler
# - `last_seen`: added by the crawler
# - `ad_created`: from the website
# - `registration_month`: from the website
# - `registration_year`: from the website
#
# The date_crawled, last_seen, and ad_created columns are all identified as string values

# %%
# Let's look the three strings date columns
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %% [markdown]
print(len(clean_date_crawled.value_counts(normalize=True, dropna=False)), len(clean_last_seen.value_counts(normalize=True, dropna=False)))
# Out:
# 34 34

# %% [markdown]
# ### Columns for date crawled and last seen seem clean

# %%
autos['registration_year'].describe()
# Out:
# count    40165.000000
# mean      2003.527723
# std         77.528587
# min       1000.000000
# 25%       1999.000000
# 50%       2002.000000
# 75%       2006.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %%
# The max shows outliers
autos['registration_year'].max()
# Out:
# 9999

# %%
autos['registration_year'].min()
# Out:
# 1000

# %%
autos['registration_year'].unique()
# Out:
# array([2004, 1997, 2009, 2007, 2003, 2006, 1995, 1998, 2000, 2017, 2010,
#        1999, 1990, 1992, 2002, 2005, 2008, 1985, 2012, 2016, 1996, 1994,
#        1986, 2001, 2018, 2011, 1993, 1988, 1989, 1973, 2013, 1967, 1976,
#        4500, 1987, 2014, 1991, 1960, 1983, 1969, 1978, 1980, 1984, 1963,
#        1977, 1972, 1961, 2015, 1934, 1982, 1966, 1979, 1968, 1981, 1970,
#        1971, 4100, 1975, 2019, 1965, 1956, 9999, 1958, 1800, 1974, 1964,
#        1950, 1962, 1959, 1937, 1000, 1910, 5000, 1952, 1111, 8888, 1941,
#        1938, 2800, 5911, 1953, 4800, 1001])

# %% [markdown]
# - The earliest year would be in the 20th century. Others will be considered as outliers

# %%
# Let's see some more outliers. 2019 is current & 1899 is cars were not invented yet
ry_bool_1 = (autos['registration_year'] > 2019) | (autos['registration_year'] < 1899) 
print(autos['registration_year'].loc[ry_bool_1].value_counts())
# Out:
# 5000    3
# 9999    2
# 1800    2
# 1001    1
# 5911    1
# 4800    1
# 1111    1
# 8888    1
# 4100    1
# 4500    1
# 1000    1
# 2800    1
# Name: registration_year, dtype: int64

# %% [markdown]
# ### Need to remove the outliers of registration year

# %%
# Let's make a filter to remove the outliers
autos.drop(autos.index[((autos['registration_year'] > 2019) |
                        (autos['registration_year'] < 1899))],
                        axis=0, inplace=True)

# %%
autos['registration_year'].describe()
# Out:
# count    40149.000000
# mean      2002.515181
# std          6.955093
# min       1910.000000
# 25%       1999.000000
# 50%       2002.000000
# 75%       2006.000000
# max       2019.000000
# Name: registration_year, dtype: float64

# %%
# Getting code from the solution and use it as reference in the future
(~autos["registration_year"].between(1900,2016)).sum() / autos.shape[0]
# Out:
# 0.04274079055518195

# %% [markdown]
# Given that this is less than 4% of our data, we will remove these rows.

# %% [markdown]
# ### Let's look at the brand column
# - select the top 20 or total values > 5%
# - make a dictionary to hold the aggregate data with brand name as the key and mean price is the value
# - sort and display by highest mean price

# %%
autos['brand'].value_counts().index
# Out:
# Index(['volkswagen', 'opel', 'bmw', 'mercedes_benz', 'ford', 'audi', 'renault',
#        'peugeot', 'fiat', 'seat', 'smart', 'mazda', 'citroen', 'nissan',
#        'skoda', 'toyota', 'hyundai', 'volvo', 'mitsubishi', 'honda',
#        'alfa_romeo', 'sonstige_autos', 'kia', 'suzuki', 'mini', 'chevrolet',
#        'chrysler', 'daihatsu', 'dacia', 'subaru', 'daewoo', 'saab', 'trabant',
#        'jeep', 'rover', 'lancia', 'land_rover', 'jaguar', 'porsche', 'lada'],
#       dtype='object')

# %%
autos['brand'].value_counts()
# Out:
# volkswagen        8659
# opel              4967
# bmw               3790
# mercedes_benz     3340
# ford              3069
# audi              2786
# renault           2235
# peugeot           1366
# fiat              1214
# seat               827
# smart              684
# mazda              676
# citroen            640
# nissan             629
# skoda              627
# toyota             553
# hyundai            405
# volvo              371
# mitsubishi         363
# honda              357
# alfa_romeo         292
# sonstige_autos     289
# kia                285
# suzuki             262
# mini               239
# chevrolet          218
# chrysler           153
# daihatsu           121
# dacia              110
# subaru              90
# daewoo              75
# saab                73
# trabant             65
# jeep                64
# rover               64
# lancia              49
# land_rover          42
# jaguar              41
# porsche             30
# lada                29
# ...

# %%
# Storing the brand and mean price into a dictionary
top_brand_cars = {}
brands = autos['brand'].unique()
for b in brands:
    selected_rows = autos[autos['brand'] == b]
    price = selected_rows['price'].mean()
    if b not in top_brand_cars:
        top_brand_cars[b] = price

# %%
sorted(top_brand_cars.items(), key=lambda kv: kv[1], reverse=True)
# Out:
# [('porsche', 6493.266666666666),
#  ('mini', 6366.158995815899),
#  ('jeep', 5119.5),
#  ('dacia', 4800.272727272727),
#  ('skoda', 4356.354066985646),
#  ('land_rover', 4280.619047619048),
#  ('bmw', 4197.988126649077),
#  ('sonstige_autos', 4050.553633217993),
#  ('chevrolet', 4018.761467889908),
#  ('toyota', 4005.766726943942),
#  ('audi', 3982.930007178751),
#  ('mercedes_benz', 3924.2407185628745),
#  ('jaguar', 3857.1463414634145),
#  ('kia', 3746.985964912281),
#  ('hyundai', 3723.617283950617),
#  ('smart', 3454.83918128655),
#  ('suzuki', 3371.0496183206105),
#  ('volkswagen', 3210.955422104169),
#  ('seat', 3167.484885126965),
#  ('citroen', 3074.684375),
#  ('honda', 3029.0672268907565),
#  ('volvo', 2980.811320754717),
#  ('mazda', 2972.96449704142),
#  ('alfa_romeo', 2895.0171232876714),
#  ('nissan', 2778.330683624801),
#  ('peugeot', 2649.7071742313324),
#  ('lada', 2647.7241379310344),
#  ('chrysler', 2541.97385620915),
#  ('fiat', 2476.3855024711697),
# ...

# %%
# Codes from the solution
brand_counts = autos["brand"].value_counts(normalize=True)
common_brands = brand_counts[brand_counts > .05].index
print(common_brands)

brand_mean_prices = {}
for brand in common_brands:
    brand_only = autos[autos["brand"] == brand]
    mean_price = brand_only["price"].mean()
    brand_mean_prices[brand] = int(mean_price)

brand_mean_prices
# Out:
# Index(['volkswagen', 'opel', 'bmw', 'mercedes_benz', 'ford', 'audi',
#        'renault'],
#       dtype='object')
# {'audi': 3982,
#  'bmw': 4197,
#  'ford': 2445,
#  'mercedes_benz': 3924,
#  'opel': 2363,
#  'renault': 2031,
#  'volkswagen': 3210}

# %%
sorted(brand_mean_prices.items(), key=lambda kv: kv[1], reverse=True)
# Out:
# [('bmw', 4197),
#  ('audi', 3982),
#  ('mercedes_benz', 3924),
#  ('volkswagen', 3210),
#  ('ford', 2445),
#  ('opel', 2363),
#  ('renault', 2031)]

# %%
# Top brands with mean mileage
brand_mean_mileage = {}
for brand in common_brands:
    brand_only = autos[autos['brand'] == brand]
    mean_mileage = brand_only['odometer_km'].mean()
    brand_mean_mileage[brand] = int(mean_mileage)

brand_mean_mileage
# Out:
# {'audi': 144554,
#  'bmw': 141949,
#  'ford': 129248,
#  'mercedes_benz': 141214,
#  'opel': 132866,
#  'renault': 130592,
#  'volkswagen': 136659}

# %%
sorted(brand_mean_mileage.items(), key=lambda kv: kv[1], reverse=True)
# Out:
# [('audi', 144554),
#  ('bmw', 141949),
#  ('mercedes_benz', 141214),
#  ('volkswagen', 136659),
#  ('opel', 132866),
#  ('renault', 130592),
#  ('ford', 129248)]

# %%
# Make pandas series and dataframe constructor
bmp_series = pd.Series(brand_mean_prices)
bmm_series = pd.Series(brand_mean_mileage)
df = pd.DataFrame(bmp_series, columns=['mean price'])
df['mean_mileage'] = bmm_series
df
# Out:
#                mean price  mean_mileage
# audi                 3982        144554
# bmw                  4197        141949
# ford                 2445        129248
# mercedes_benz        3924        141214
# opel                 2363        132866
# renault              2031        130592
# volkswagen           3210        136659

# %% [markdown]
# Based on sorting the highest values, the top brands mean price has the top brands mean mileage.
